# %% [markdown]
# <a href="https://colab.research.google.com/github/anarchy373/BTECH-Python-Projects/blob/main/Web_Scraping_Module_2_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
response = requests.get('https://btech-data-analytics.github.io/bridgerland-technical-college/bookstore.html').text

# %%
soup = BeautifulSoup(response, 'html.parser')

# %%
print(response)
# Out:
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <link rel="stylesheet" href="https://www.w3schools.com/w3css/4/w3.css">
#     <link rel="stylesheet" href="style.css">
#     <title>Bob's Bookstore</title>
# </head>
# <body>
#     <div class="w3-bar w3-blue-grey w3-large" style="padding: 0rem 8rem 0rem 8rem">
#         <a href="/bridgerland-technical-college/home.html"><img src="bobs_bookstore_white.png" class="" style="max-height: 2.8rem;"></a>
#         <a href="/bridgerland-technical-college/bookstore.html" class="w3-bar-item w3-button w3-right">Store</a>
#         <a href="/bridgerland-technical-college/contact.html" class="w3-bar-item w3-button w3-right">Contact</a>
#         <a href="/bridgerland-technical-college/about.html" class="w3-bar-item w3-button w3-right">About</a>
#       </div>
#
#       <div style="max-width: 1000px;margin: auto;" class="w3-container">
# ...

# %%
author = []
pages = []
topic = []
price = []



for book in soup.find('table').find_all('tr', class_='book'):
    author.append(book.find_all('td')[2].text)
    pages.append(book.find_all('td')[4].text)
    topic.append(book.find_all('td')[5].text)
    price.append(book.find_all('td')[6].text)

# %%
df = pd.DataFrame({
      'author' : author,
      'pages' : pages,
      'topic' : topic,
      'price' : price
})
df.head(20)
# Out:
#                  author pages topic   price
# 0   Penelope Wainwright   256  Cats  $19.99
# 1       Jasper Sterling   192  Cats  $15.99
# 2   Penelope Wainwright   320  Cats  $21.99
# 3     Maximilian Thorne   288  Cats  $17.99
# 4    Isadora Harrington   224  Cats  $16.99
# 5   Penelope Wainwright   288  Cats  $20.99
# 6       Jasper Sterling   192  Cats  $14.99
# 7    Celeste Nightshade   240  Cats  $18.99
# 8   Penelope Wainwright   208  Cats  $16.99
# 9    Seraphina Montague   176  Cats  $12.99
# 10     Benjamin Barkley   256  Dogs  $29.99
# 11      Sophie Shepherd   192  Dogs  $25.99
# 12     Oliver Obedience   320  Dogs  $21.99
# 13      Ruby Ruffington   288  Dogs  $27.99
# 14     Benjamin Barkley   224  Dogs  $26.99

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   author  15 non-null     object
#  1   pages   15 non-null     object
#  2   topic   15 non-null     object
#  3   price   15 non-null     float64
# dtypes: float64(1), object(3)
# memory usage: 608.0+ bytes

# %%
# Group by topic and count the number of books
topic_book_counts = df['topic'].value_counts()

# Find the topic with the most books
most_books_topic = topic_book_counts.idxmax()
max_books_count = topic_book_counts.max()

print(f"The author with the most books is {most_books_author} with {max_books_count} books.")
# Out:
# The author with the most books is Cats with 10 books.

# %%
# Remove the dollar symbols and convert the 'Price' column to float
# df['price'] = df['price'].str.replace('$', '').astype(float)


# Group by topic and count the number of books
average_price_by_topic = df.groupby('topic')['price'].mean()

# Find the topic with the highest average price
most_expensive_topic = average_price_by_topic.idxmax()
highest_average_price = average_price_by_topic.max()

print(f"The most expensive topic, on average, is '{most_expensive_topic}' with an average price of ${highest_average_price:.2f}.")
# Out:
# The most expensive topic, on average, is 'Dogs' with an average price of $26.59.

# %%
# Convert 'pages' column to an integer
df['pages'] = df['pages'].astype(int)


# Group by topic and calculate the average number of pages
average_pages_by_topic = df.groupby('topic')['pages'].mean()

# Find the topic with the highest average number of pages
most_pages_topic = average_pages_by_topic.idxmax()
highest_average_pages = average_pages_by_topic.max()

print(f"The topic with the most pages, on average, is '{most_pages_topic}' with an average of {highest_average_pages:.2f} pages.")
# Out:
# The topic with the most pages, on average, is 'Dogs' with an average of 256.00 pages.
